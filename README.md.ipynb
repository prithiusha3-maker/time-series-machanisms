# %%
# Advanced Time Series Forecasting using Attention-machanisms

## Overview
This project uses an attention-based transformer model (PyTorch) for multi-feature time series forecasting, as per assignment requirements.

## Dataset
- File: timeseries_dataset.csv
- Features: Cars_Distributed, Cash_Incentive (expandable to 5+ features)
- Rows: 120 (extend to 1000 for complete assignment)

## Workflow
1. Data simulated and saved as timeseries_dataset.csv.
2. Data is windowed for sequence modeling.
3. Transformer model is constructed and trained on windowed data.
4. Forecasts next 20 days beyond training data.
5. Performance metrics (RMSE, MAE) are reported.

## How to Run
- Make sure Python 3.8+ and required packages (PyTorch, pandas, sklearn, matplotlib) are installed.
- Run `attention_transformer.py`.

## Results
- Output plot shows historical data and future predictions.
- RMSE, MAE metrics printed.

## Files
- timeseries_dataset.csv : dataset.
- attention_transformer.py : complete script.
- README.md : this documentation.

## Notes
- Expand features and data length as per assignment instructions.
- Add model comparison and hyperparameter optimization for extra marks.
